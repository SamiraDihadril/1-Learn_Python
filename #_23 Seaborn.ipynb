# %%
# Seaborn: provides an API on top of Matplotlib that offers sane choices for plot style and color defaults,
#     defines simple high-level functions for common statistical plot types,
#     and integrates with the functionality provided by Pandas


import pandas as pd
import numpy as np
import seaborn as sns

# %%
mydata =np.random.multivariate_normal([0,0],[[5,2],[2,2]],size=2000)
mydata = pd.DataFrame(data, columns=['x','y'])

sns.kdeplot(data=mydata,x='x',y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
data =np.random.multivariate_normal([0,0],[[5,2],[2,2]],size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

for col in 'xy':
    sns.kdeplot(data[col], shade=True)

# %%
data =np.random.multivariate_normal([0,0],[[5,2],[2,2]],size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

for col in 'xy':
    sns.kdeplot(data[col], shade=False)

# %%
mydata =np.random.multivariate_normal([0,0],[[5,2],[2,2]],size=2000)
mydata = pd.DataFrame(data, columns=['x', 'y'])

for col in 'xy':
    sns.kdeplot(mydata[col], shade=True)

sns.distplot(mydata['x'])
sns.distplot(mydata['y'])
# Out:
# C:\Users\Samira Dihadril\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Samira Dihadril\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='y', ylabel='Density'>

# %%
mydata =np.random.multivariate_normal([0,0],[[5,2],[2,2]],size=2000)
mydata = pd.DataFrame(data, columns=['x', 'y'])
sns.kdeplot(
    data=mydata, x="x", y="y",  fill=True,
)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>
